# %%
import torch
torch.cuda.empty_cache()

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /home/darth/MLAI-projects/yolo_conveyor/yolo_conveyor_belt

# %%
ANNOTATIONS_DIRECTORY_PATH = f"{HOME}/dataset/train_whole/labels"
IMAGES_DIRECTORY_PATH = f"{HOME}/dataset/train_whole/images"
DATA_YAML_PATH = f"{HOME}/dataset/data.yaml"

# %%
# %cd {HOME}

# from autodistill_yolov8 import YOLOv8

# target_model = YOLOv8("yolov8n.pt")
# target_model.train(DATA_YAML_PATH, epochs=50)

# %%
# !ls {HOME}/runs/detect/train2/

# %% [markdown]
# # Training

# %%
# DATA_YAML_PATH = f"{HOME}/dataset/dataset.yaml"
DATA_YAML_PATH
# Out:
# '/home/darth/MLAI-projects/yolo_conveyor/yolo_conveyor_belt/dataset/data.yaml'

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8s.pt')  # load a pretrained model (recommended for training)

# Train the model with 1 GPUs
model.train(data=DATA_YAML_PATH, epochs=100, imgsz=640, batch=8, amp=False)
# Out:
# New https://pypi.org/project/ultralytics/8.0.134 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.6 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 5934MiB)
# ...

# %%
# !yolo predict model="runs/detect/train17/weights/best.pt" source="images/video2-00023.png"
# Out:
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.6 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 5934MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /home/darth/MLAI-projects/yolo_conveyor/yolo_conveyor_belt/images/video2-00023.png: 384x640 35 chocolates, 58.6ms
# Speed: 0.5ms preprocess, 58.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict14

# %%
# !yolo predict model="runs/detect/train17/weights/best.pt" source="raw_video/conveyor_chocolate.mp4"
# Out:
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.6 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 5934MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (1/457) /home/darth/MLAI-projects/yolo_conveyor/yolo_conveyor_belt/raw_video/conveyor_chocolate.mp4: 384x640 34 chocolates, 58.1ms
# video 1/1 (2/457) /home/darth/MLAI-projects/yolo_conveyor/yolo_conveyor_belt/raw_video/conveyor_chocolate.mp4: 384x640 34 chocolates, 6.7ms
# video 1/1 (3/457) /home/darth/MLAI-projects/yolo_conveyor/yolo_conveyor_belt/raw_video/conveyor_chocolate.mp4: 384x640 34 chocolates, 7.2ms
# video 1/1 (4/457) /home/darth/MLAI-projects/yolo_conveyor/yolo_conveyor_belt/raw_video/conveyor_chocolate.mp4: 384x640 33 chocolates, 7.7ms
# video 1/1 (5/457) /home/darth/MLAI-projects/yolo_conveyor/yolo_conveyor_belt/raw_video/conveyor_chocolate.mp4: 384x640 33 chocolates, 7.7ms
# ...
